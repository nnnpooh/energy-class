# %% [markdown]
# # LSTM
# - Air Quality Data in India
# - https://www.kaggle.com/rohanrao/air-quality-data-in-india
# - city_day.csv

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Load data

# %%
import numpy as np
import pandas as pd
df_all = pd.read_csv('city_day.csv')
#df_all = pd.read_csv('https://raw.githubusercontent.com/nnnpooh/energy-class/main/T2%20-%20ARIMA/city_day.csv')
df_all.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %% [markdown]
# ## Filtering

# %%
# Filter only Delhi
df_delhi = df_all.loc[df_all['City'] == 'Delhi'].copy()
df_delhi.head()
# Out:
#         City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
#
#         SO2     O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 10229  9.25  41.68    14.36    24.86    9.84  472.0     Severe
# 10230  6.65  29.97    10.55    20.09    4.29  454.0     Severe
# 10231  2.65  19.71     3.91    10.23    1.99  143.0   Moderate
# 10232  4.63  25.36     4.26     9.71    3.34  319.0  Very Poor
# 10233  3.33  23.20     2.80     6.21    2.96  325.0  Very Poor

# %%
# Choose 2 columns
df_delhi = df_delhi[['Date','AQI']]
df_delhi.head()
# Out:
#              Date    AQI
# 10229  2015-01-01  472.0
# 10230  2015-01-02  454.0
# 10231  2015-01-03  143.0
# 10232  2015-01-04  319.0
# 10233  2015-01-05  325.0

# %%
# Set index
df_delhi['Date'] = pd.to_datetime(df_delhi['Date'])
df = df_delhi.set_index('Date')
df.head()
# Out:
#               AQI
# Date
# 2015-01-01  472.0
# 2015-01-02  454.0
# 2015-01-03  143.0
# 2015-01-04  319.0
# 2015-01-05  325.0

# %% [markdown]
# ## Resampling
# - Note that for day resampling (D), there is missing data.

# %%
max_sample = -1
df_avg = df['AQI'].resample('MS').mean()
#df_avg = df['AQI'].resample('D').mean()
if max_sample > 0:
    df_avg = df_avg.iloc[-max_sample-1:-1]
# Make sure we have the dataframe at the end
df_avg = pd.DataFrame(df_avg)
df_avg.columns = ['y']
df_avg.head()
# Out:
#                      y
# Date
# 2015-01-01  342.290323
# 2015-02-01  327.928571
# 2015-03-01  256.064516
# 2015-04-01  305.266667
# 2015-05-01  348.580645

# %%
# Check for missing value
df_avg.info()
#df_avg[df_avg.isna().any(axis=1)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 67 entries, 2015-01-01 to 2020-07-01
# Freq: MS
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       67 non-null     float64
# dtypes: float64(1)
# memory usage: 1.0 KB

# %% [markdown]
# ## Replace missing values
# - Using rolling average

# %%
n_rows = df_avg[df_avg.isna().any(axis=1)].shape[0]
print(f"Number NaN rows are {n_rows}.")
if n_rows > 0:
    print(f"Replace missing values with rolling average.")
    df_rolling = df_avg['y'].rolling(24,min_periods=1,).mean()
    df_avg['y'] = df_avg['y'].fillna(df_rolling)
# Out:
# Number NaN rows are 0.

# %%
import matplotlib.pyplot as plt
df_avg.plot(figsize=(10, 3))
plt.show()

# %% [markdown]
# ## Scaling data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_avg['y (scaled)'] = scaler.fit_transform(df_avg[['y']])
display(df_avg.head())
# Out:
#                      y  y (scaled)
# Date
# 2015-01-01  342.290323    0.674878
# 2015-02-01  327.928571    0.639650
# 2015-03-01  256.064516    0.463371
# 2015-04-01  305.266667    0.584061
# 2015-05-01  348.580645    0.690308

# %% [markdown]
# ## Converting time series into supervised data

# %%
window_size = 10

# %%
dft = df_avg.copy()
dft['split'] = ''
for i in range(1, window_size + 1):
    col = f"t-{i}" 
    dft[col] = dft.iloc[:,1].shift(i)
display(dft.head())
display(dft.tail())
# Out:
#                      y  y (scaled) split       t-1       t-2       t-3  \
# Date
# 2015-01-01  342.290323    0.674878             NaN       NaN       NaN
# 2015-02-01  327.928571    0.639650        0.674878       NaN       NaN
# 2015-03-01  256.064516    0.463371        0.639650  0.674878       NaN
# 2015-04-01  305.266667    0.584061        0.463371  0.639650  0.674878
# 2015-05-01  348.580645    0.690308        0.584061  0.463371  0.639650
#
#                  t-4  t-5  t-6  t-7  t-8  t-9  t-10
# Date
# 2015-01-01       NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2015-02-01       NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2015-03-01       NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2015-04-01       NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2015-05-01  0.674878  NaN  NaN  NaN  NaN  NaN   NaN
#                      y  y (scaled) split       t-1       t-2       t-3  \
# Date
# 2020-03-01  135.838710    0.168462        0.478268  0.591874  0.703364
# 2020-04-01  113.000000    0.112440        0.168462  0.478268  0.591874
# 2020-05-01  148.645161    0.199876        0.112440  0.168462  0.478268
# 2020-06-01  125.733333    0.143674        0.199876  0.112440  0.168462
# 2020-07-01  101.000000    0.083005        0.143674  0.199876  0.112440
#
#                  t-4       t-5       t-6       t-7       t-8       t-9  \
# Date
# 2020-03-01  0.708753  0.450948  0.096578  0.078811  0.191172  0.320369
# 2020-04-01  0.703364  0.708753  0.450948  0.096578  0.078811  0.191172
# 2020-05-01  0.591874  0.703364  0.708753  0.450948  0.096578  0.078811
# 2020-06-01  0.478268  0.591874  0.703364  0.708753  0.450948  0.096578
# 2020-07-01  0.168462  0.478268  0.591874  0.703364  0.708753  0.450948
#
#                 t-10
# Date
# 2020-03-01  0.413758
# 2020-04-01  0.320369
# 2020-05-01  0.191172
# 2020-06-01  0.078811
# 2020-07-01  0.096578

# %%
dft = dft.dropna()

# %% [markdown]
# ## Split data into training and testing set

# %%
test_size = 0.2
n_rows = dft.shape[0]
train_size = int(n_rows * (1-test_size))
test_size = n_rows - train_size
dft.iloc[0:train_size, 2] = 'train'
dft.iloc[train_size:, 2] = 'test'

# %%
dft.head()
# Out:
#                      y  y (scaled)  split       t-1       t-2       t-3  \
# Date
# 2015-11-01  405.033333    0.828784  train  0.632466  0.387907  0.370158
# 2015-12-01  355.322581    0.706846  train  0.828784  0.632466  0.387907
# 2016-01-01  441.903226    0.919224  train  0.706846  0.828784  0.632466
# 2016-02-01  312.448276    0.601677  train  0.919224  0.706846  0.828784
# 2016-03-01  230.096774    0.399673  train  0.601677  0.919224  0.706846
#
#                  t-4       t-5       t-6       t-7       t-8       t-9  \
# Date
# 2015-11-01  0.326559  0.468936  0.690308  0.584061  0.463371  0.639650
# 2015-12-01  0.370158  0.326559  0.468936  0.690308  0.584061  0.463371
# 2016-01-01  0.387907  0.370158  0.326559  0.468936  0.690308  0.584061
# 2016-02-01  0.632466  0.387907  0.370158  0.326559  0.468936  0.690308
# 2016-03-01  0.828784  0.632466  0.387907  0.370158  0.326559  0.468936
#
#                 t-10
# Date
# 2015-11-01  0.674878
# 2015-12-01  0.639650
# 2016-01-01  0.463371
# 2016-02-01  0.584061
# 2016-03-01  0.690308

# %%
filt = dft['split'] == 'train'
X_train = dft[filt].iloc[:,3:].values
y_train = dft[filt].iloc[:,1].values
#
filt = dft['split'] == 'test'
X_test = dft[filt].iloc[:,3:].values
y_test = dft[filt].iloc[:,1].values
#
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (45, 10)
# (12, 10)
# (45,)
# (12,)

# %% [markdown]
# ## Reshape input data for LSTM traning
# - Dimension: \[samples, time steps, features\]

# %%
X_train_rs = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test_rs = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
#
print(X_train_rs.shape)
print(X_test_rs.shape)
# Out:
# (45, 1, 10)
# (12, 1, 10)

# %% [markdown]
# # Training model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Model building

# %%
model = Sequential()
model.add(LSTM(200, input_shape=(X_train_rs.shape[1], X_train_rs.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ## Training

# %%
history = model.fit(X_train_rs, y_train, epochs=100, batch_size=10, validation_data=(X_test_rs, y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=20)], verbose=1, shuffle=False)

model.summary()
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2719 - val_loss: 0.0990
# Epoch 2/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1596 - val_loss: 0.0683
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1013 - val_loss: 0.0624
# Epoch 4/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0758 - val_loss: 0.0706
# Epoch 5/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0712 - val_loss: 0.0770
# Epoch 6/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0761 - val_loss: 0.0732
# Epoch 7/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0672 - val_loss: 0.0652
# Epoch 8/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0645 - val_loss: 0.0585
# Epoch 9/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0613 - val_loss: 0.0541
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0602 - val_loss: 0.0517
# Epoch 11/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0557 - val_loss: 0.0503
# Epoch 12/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0557 - val_loss: 0.0495
# Epoch 13/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0561 - val_loss: 0.0486
# Epoch 14/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0532 - val_loss: 0.0475
# Epoch 15/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0481 - val_loss: 0.0462
# Epoch 16/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0484 - val_loss: 0.0444
# Epoch 17/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0490 - val_loss: 0.0421
# Epoch 18/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0445 - val_loss: 0.0400
# Epoch 19/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0450 - val_loss: 0.0383
# Epoch 20/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0421 - val_loss: 0.0370
# Epoch 21/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0407 - val_loss: 0.0359
# Epoch 22/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0382 - val_loss: 0.0349
# Epoch 23/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0368 - val_loss: 0.0337
# Epoch 24/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0375 - val_loss: 0.0320
# Epoch 25/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0338 - val_loss: 0.0303
# Epoch 26/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0345 - val_loss: 0.0289
# Epoch 27/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0337 - val_loss: 0.0279
# Epoch 28/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0338 - val_loss: 0.0270
# Epoch 29/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0304 - val_loss: 0.0261
# Epoch 30/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0287 - val_loss: 0.0250
# Epoch 31/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0285 - val_loss: 0.0241
# Epoch 32/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0260 - val_loss: 0.0230
# Epoch 33/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0258 - val_loss: 0.0218
# Epoch 34/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.0210
# Epoch 35/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0227 - val_loss: 0.0205
# Epoch 36/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0233 - val_loss: 0.0193
# Epoch 37/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0254 - val_loss: 0.0188
# Epoch 38/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0230 - val_loss: 0.0187
# Epoch 39/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0208 - val_loss: 0.0186
# Epoch 40/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0173
# Epoch 41/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0154
# Epoch 42/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0210 - val_loss: 0.0146
# Epoch 43/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0147
# Epoch 44/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0152
# Epoch 45/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0143
# Epoch 46/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0139
# Epoch 47/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0189 - val_loss: 0.0135
# Epoch 48/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0199 - val_loss: 0.0126
# Epoch 49/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0197 - val_loss: 0.0137
# Epoch 50/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0142
# Epoch 51/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.0133
# Epoch 52/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0123
# Epoch 53/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0120
# Epoch 54/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0126
# Epoch 55/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.0129
# Epoch 56/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0167 - val_loss: 0.0119
# Epoch 57/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.0121
# Epoch 58/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0131
# Epoch 59/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0140 - val_loss: 0.0138
# Epoch 60/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0167 - val_loss: 0.0118
# Epoch 61/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0155 - val_loss: 0.0116
# Epoch 62/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0157 - val_loss: 0.0134
# Epoch 63/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.0117
# Epoch 64/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0166 - val_loss: 0.0109
# Epoch 65/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0173 - val_loss: 0.0119
# Epoch 66/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0176 - val_loss: 0.0122
# Epoch 67/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0157 - val_loss: 0.0120
# Epoch 68/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0167 - val_loss: 0.0127
# Epoch 69/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0165 - val_loss: 0.0118
# Epoch 70/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0107
# Epoch 71/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.0119
# Epoch 72/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0159 - val_loss: 0.0141
# Epoch 73/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0169 - val_loss: 0.0116
# Epoch 74/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0152 - val_loss: 0.0104
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0164 - val_loss: 0.0115
# Epoch 76/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0157 - val_loss: 0.0120
# Epoch 77/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0149 - val_loss: 0.0117
# Epoch 78/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.0108
# Epoch 79/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0168 - val_loss: 0.0114
# Epoch 80/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0160 - val_loss: 0.0119
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0155 - val_loss: 0.0115
# Epoch 82/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.0119
# Epoch 83/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0143 - val_loss: 0.0112
# Epoch 84/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0157 - val_loss: 0.0107
# Epoch 85/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0157 - val_loss: 0.0103
# Epoch 86/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0160 - val_loss: 0.0109
# Epoch 87/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0132
# Epoch 88/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0168 - val_loss: 0.0122
# Epoch 89/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.0106
# Epoch 90/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0167 - val_loss: 0.0108
# Epoch 91/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.0110
# Epoch 92/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0113
# Epoch 93/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0145 - val_loss: 0.0118
# Epoch 94/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0157 - val_loss: 0.0136
# Epoch 95/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0135 - val_loss: 0.0121
# Epoch 96/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0114
# Epoch 97/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0157 - val_loss: 0.0114
# Epoch 98/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0136 - val_loss: 0.0115
# Epoch 99/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0150 - val_loss: 0.0117
# Epoch 100/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0133 - val_loss: 0.0110
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200)               168800
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 169,001
# Trainable params: 169,001
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predictions

# %%
# Creating new DataFrame to store results
dft_result = dft.iloc[:,0:3]

# Model predictions
y_pred_train = model.predict(X_train_rs)
y_pred_test = model.predict(X_test_rs)
y_pred = np.concatenate((y_pred_train, y_pred_test), axis=0)

# Invert predictions
y_pred_train_pl = scaler.inverse_transform(y_pred_train)
y_pred_test_pl = scaler.inverse_transform(y_pred_test)
y_pred_pl = scaler.inverse_transform(y_pred)

# Storing results
dft_result['y_pred (scaled)'] = y_pred 
dft_result['y_pred'] = y_pred_pl

# %%
dft_result.head()
# Out:
#                      y  y (scaled)  split  y_pred (scaled)      y_pred
# Date
# 2015-11-01  405.033333    0.828784  train         0.755405  375.118988
# 2015-12-01  355.322581    0.706846  train         0.737700  367.901062
# 2016-01-01  441.903226    0.919224  train         0.548442  290.745941
# 2016-02-01  312.448276    0.601677  train         0.743933  370.441864
# 2016-03-01  230.096774    0.399673  train         0.542201  288.201630

# %% [markdown]
# ## Evaluation

# %%
def model_eval(df_eval):
    MAE = dft_eval['error'].abs().mean()
    RMSE = np.sqrt((dft_eval['error']**2).mean())
    MAPE = dft_eval['percentage'].abs().mean()
    print(f"-------")
    print(f"Mean absolute error: {MAE:6.3f}")
    print(f"Root mean squared error: {RMSE:6.3f}")
    print(f"Mean absolute percentage error: {MAPE:6.3f}")

# %%
dft_result['error'] = dft_result['y'] - dft_result['y_pred']
dft_result['percentage'] = dft_result['error']/dft_result['y']*100

dft_eval = dft_result[dft_result['split'] == 'train']
print(f"Training")
model_eval(dft_eval)

print(f"\nTesting")
dft_eval = dft_result[dft_result['split'] == 'test']
model_eval(dft_eval)

print(f"\nAll")
model_eval(dft_result)
# Out:
# Training
# -------
# Mean absolute error: 37.211
# Root mean squared error: 48.052
# Mean absolute percentage error: 15.796
#
# Testing
# -------
# Mean absolute error: 33.437
# Root mean squared error: 42.733
# Mean absolute percentage error: 25.732
#
# All
# -------
# Mean absolute error: 33.437
# Root mean squared error: 42.733
# Mean absolute percentage error: 25.732

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))

dft_plot = dft_result[dft_result['split'] == 'train']
dft_plot[['y', 'y_pred']].plot(ax=ax1)
ax1.set_title('Training data')

dft_plot = dft_result[dft_result['split'] == 'test']
dft_plot[['y', 'y_pred']].plot(ax=ax2)
ax2.set_title('Testing data')

plt.show()

# %% [markdown]
# # Forecasting

# %% [markdown]
# ## Retrain the model with entire data

# %%
# Extract data
X_train = dft.iloc[:,3:].values
y_train = dft.iloc[:,1].values

# Reshape data
X_train_rs = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])

print(X_train_rs.shape)
print(y_train.shape)
# Out:
# (57, 1, 10)
# (57,)

# %%
history = model.fit(X_train_rs, y_train, epochs=100, batch_size=10, validation_data=(X_test_rs, y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=20)], verbose=1, shuffle=False)

model.summary()
# Out:
# Epoch 1/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.0295WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0115
# Epoch 2/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0143 - val_loss: 0.0093
# Epoch 3/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0140 - val_loss: 0.0099
# Epoch 4/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0149 - val_loss: 0.0091
# Epoch 5/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0126 - val_loss: 0.0087
# Epoch 6/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0154 - val_loss: 0.0102
# Epoch 7/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.0086
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0142 - val_loss: 0.0088
# Epoch 9/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.0093
# Epoch 10/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0082
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0076
# Epoch 12/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0079
# Epoch 13/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0132 - val_loss: 0.0088
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0081
# Epoch 15/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.0081
# Epoch 16/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0086
# Epoch 17/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0141 - val_loss: 0.0073
# Epoch 18/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0137 - val_loss: 0.0080
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.0078
# Epoch 20/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0077
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0143 - val_loss: 0.0077
# Epoch 22/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0131 - val_loss: 0.0075
# Epoch 23/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0126 - val_loss: 0.0077
# Epoch 24/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0135 - val_loss: 0.0070
# Epoch 25/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0128 - val_loss: 0.0072
# Epoch 26/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0125 - val_loss: 0.0072
# Epoch 27/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0079
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0126 - val_loss: 0.0075
# Epoch 29/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0069
# Epoch 30/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.0073
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0077
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0133 - val_loss: 0.0075
# Epoch 33/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0069
# Epoch 34/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0137 - val_loss: 0.0071
# Epoch 35/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0128 - val_loss: 0.0069
# Epoch 36/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0119 - val_loss: 0.0067
# Epoch 37/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.0073
# Epoch 38/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.0062
# Epoch 39/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0133 - val_loss: 0.0066
# Epoch 40/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.0078
# Epoch 41/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0072
# Epoch 42/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0118 - val_loss: 0.0067
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0144 - val_loss: 0.0068
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0128 - val_loss: 0.0067
# Epoch 45/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.0063
# Epoch 46/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.0066
# Epoch 47/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0147 - val_loss: 0.0067
# Epoch 48/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.0065
# Epoch 49/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0070
# Epoch 50/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.0060
# Epoch 51/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0119 - val_loss: 0.0061
# Epoch 52/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0119 - val_loss: 0.0074
# Epoch 53/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0134 - val_loss: 0.0062
# Epoch 54/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.0057
# Epoch 55/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.0074
# Epoch 56/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0124 - val_loss: 0.0062
# Epoch 57/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0060
# Epoch 58/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0116 - val_loss: 0.0070
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0123 - val_loss: 0.0059
# Epoch 60/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0125 - val_loss: 0.0059
# Epoch 61/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0137 - val_loss: 0.0071
# Epoch 62/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0124 - val_loss: 0.0062
# Epoch 63/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.0054
# Epoch 64/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0065
# Epoch 65/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0067
# Epoch 66/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0055
# Epoch 67/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0060
# Epoch 68/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0115 - val_loss: 0.0061
# Epoch 69/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0065
# Epoch 70/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0131 - val_loss: 0.0053
# Epoch 71/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0116 - val_loss: 0.0059
# Epoch 72/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0109 - val_loss: 0.0063
# Epoch 73/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0118 - val_loss: 0.0058
# Epoch 74/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0127 - val_loss: 0.0059
# Epoch 75/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.0064
# Epoch 76/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0116 - val_loss: 0.0060
# Epoch 77/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.0060
# Epoch 78/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0066
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0121 - val_loss: 0.0060
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0127 - val_loss: 0.0060
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.0061
# Epoch 82/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0111 - val_loss: 0.0056
# Epoch 83/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0117 - val_loss: 0.0070
# Epoch 84/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.0056
# Epoch 85/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0121 - val_loss: 0.0054
# Epoch 86/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0125 - val_loss: 0.0067
# Epoch 87/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0116 - val_loss: 0.0055
# Epoch 88/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.0057
# Epoch 89/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0056
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.0066
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200)               168800
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 169,001
# Trainable params: 169,001
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Storing prediction result

# %%
y_pred = model.predict(X_train_rs)
y_pred_pl = scaler.inverse_transform(y_pred)
dft_result['y_pred_2 (scale)'] = y_pred
dft_result['y_pred_2'] = y_pred_pl
display(dft_result.head())
# Out:
#                      y  y (scaled)  split  y_pred (scaled)      y_pred  \
# Date
# 2015-11-01  405.033333    0.828784  train         0.755405  375.118988
# 2015-12-01  355.322581    0.706846  train         0.737700  367.901062
# 2016-01-01  441.903226    0.919224  train         0.548442  290.745941
# 2016-02-01  312.448276    0.601677  train         0.743933  370.441864
# 2016-03-01  230.096774    0.399673  train         0.542201  288.201630
#
#                  error  percentage  y_pred_2 (scale)    y_pred_2
# Date
# 2015-11-01   29.914345    7.385650          0.813693  398.881256
# 2015-12-01  -12.578481   -3.540017          0.756665  375.632507
# 2016-01-01  151.157285   34.205970          0.600711  312.054321
# 2016-02-01  -57.993588  -18.561020          0.804785  395.249481
# 2016-03-01  -58.104855  -25.252356          0.539897  287.262085

# %% [markdown]
# ## Forecasting

# %%
n_forecast = 10

# %%
y = dft_result['y (scaled)'].values
freq = dft_result.index.freq
dt_last = dft_result.index[-1]
dts = []
for i in range(1,n_forecast+1):
    x = y[-window_size-1:-1]
    x = x.reshape(1,1,-1)
    y = np.append(y,model.predict(x).flatten())
    dts.append(dt_last + freq * i)

y_fore = y[-n_forecast-1:-1]
y_fore_pl = scaler.inverse_transform([y_fore]).ravel()

dft_forecast = pd.DataFrame( {'date_time': dts, 'y_fore (scaled)': y_fore, 'y_fore': y_fore_pl} )
dft_forecast = dft_forecast.set_index('date_time')
dft_forecast.head()
# Out:
#             y_fore (scaled)      y_fore
# date_time
# 2020-08-01         0.083005  101.000000
# 2020-09-01         0.124989  118.115825
# 2020-10-01         0.290722  185.680418
# 2020-11-01         0.438155  245.784650
# 2020-12-01         0.608909  315.396446

# %%
fig, ax = plt.subplots(figsize=(10,5))
dft_result['y'].plot(ax=ax)
dft_result['y_pred_2'].plot(ax=ax)
dft_forecast['y_fore'].plot(ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
dft_result['y'].plot(ax=ax)
dft_result['y_pred_2'].plot(ax=ax)
dft_forecast['y_fore'].plot(ax=ax)

dt_start = dft_result.index[-n_forecast*15]
dt_end = dft_forecast.index[-1]
ax.set_xlim(dt_start,dt_end)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-d854b83a9009> in <module>
#       4 dft_forecast['y_fore'].plot(ax=ax)
#       5
# ----> 6 dt_start = dft_result.index[-n_forecast*15]
#       7 dt_end = dft_forecast.index[-1]
#       8 ax.set_xlim(dt_start,dt_end)
#
# ~\miniconda3\envs\tf\lib\site-packages\pandas\core\indexes\extension.py in __getitem__(self, key)
#     236
#     237     def __getitem__(self, key):
# --> 238         result = self._data[key]
#     239         if isinstance(result, type(self._data)):
#     240             if result.ndim == 1:
#
# ~\miniconda3\envs\tf\lib\site-packages\pandas\core\arrays\datetimelike.py in __getitem__(self, key)
#     279         only handle list-likes, slices, and integer scalars
#     280         """
# --> 281         result = super().__getitem__(key)
#     282         if lib.is_scalar(result):
#     283             return result
#
# ~\miniconda3\envs\tf\lib\site-packages\pandas\core\arrays\_mixins.py in __getitem__(self, key)
#     220         if lib.is_integer(key):
#     221             # fast-path
# --> 222             result = self._ndarray[key]
#     223             if self.ndim == 1:
#     224                 return self._box_func(result)
#
# IndexError: index -150 is out of bounds for axis 0 with size 57
