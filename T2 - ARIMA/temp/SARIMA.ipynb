# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#define function for kpss test
from statsmodels.tsa.stattools import kpss
#define KPSS
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
series = pd.read_csv('city_day.csv')
series_delhi = series.loc[series['City'] == 'Delhi']
ts_delhi = series_delhi[['Date','AQI']]
#converting 'Date' column to type 'datetime' so that indexing can happen later
ts_delhi['Date'] = pd.to_datetime(ts_delhi['Date'])

display(ts_delhi)
# Out:
#             Date    AQI
# 10229 2015-01-01  472.0
# 10230 2015-01-02  454.0
# 10231 2015-01-03  143.0
# 10232 2015-01-04  319.0
# 10233 2015-01-05  325.0
# ...          ...    ...
# 12233 2020-06-27  112.0
# 12234 2020-06-28  196.0
# 12235 2020-06-29  233.0
# 12236 2020-06-30  114.0
# 12237 2020-07-01  101.0
#
# [2009 rows x 2 columns]

# %%
ts_delhi['Date'].min(), ts_delhi['Date'].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2020-07-01 00:00:00'))

# %%
ts_delhi.isnull().sum()
ts_delhi = ts_delhi.dropna()
ts_delhi.isnull().sum()
# Out:
# Date    0
# AQI     0
# dtype: int64

# %%
ts_delhi = ts_delhi.set_index('Date')
display(ts_delhi)
# Out:
#               AQI
# Date
# 2015-01-01  472.0
# 2015-01-02  454.0
# 2015-01-03  143.0
# 2015-01-04  319.0
# 2015-01-05  325.0
# ...           ...
# 2020-06-27  112.0
# 2020-06-28  196.0
# 2020-06-29  233.0
# 2020-06-30  114.0
# 2020-07-01  101.0
#
# [1999 rows x 1 columns]

# %%
ts_month_avg = ts_delhi['AQI'].resample('MS').mean()
display(ts_month_avg)
# Out:
# Date
# 2015-01-01    342.290323
# 2015-02-01    327.928571
# 2015-03-01    256.064516
# 2015-04-01    305.266667
# 2015-05-01    348.580645
#                  ...
# 2020-03-01    135.838710
# 2020-04-01    113.000000
# 2020-05-01    148.645161
# 2020-06-01    125.733333
# 2020-07-01    101.000000
# Freq: MS, Name: AQI, Length: 67, dtype: float64

# %%
display(ts_month_avg.tail())
# Out:
# Date
# 2020-03-01    135.838710
# 2020-04-01    113.000000
# 2020-05-01    148.645161
# 2020-06-01    125.733333
# 2020-07-01    101.000000
# Freq: MS, Name: AQI, dtype: float64

# %%
ts_month_avg.plot(figsize=(15, 6))
plt.show()
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_month_avg, lags=30)
matplotlib.pyplot.show()
plot_pacf(ts_month_avg, lags=30)
matplotlib.pyplot.show()

from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(ts_month_avg, model='additive')
fig = decomposition.plot()
plt.show()

# %%
#apply adf test on the series
print(adf_test(ts_month_avg))
print(kpss_test(ts_month_avg))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  0.229024
# p-value                         0.973843
# #Lags Used                     11.000000
# Number of Observations Used    55.000000
# Critical Value (1%)            -3.555273
# Critical Value (5%)            -2.915731
# Critical Value (10%)           -2.595670
# dtype: float64
# None
# Results of KPSS Test:
# Test Statistic            0.650669
# p-value                   0.018030
# Lags Used                11.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
ts_t_adj = ts_month_avg - ts_month_avg.shift(1)
ts_t_adj = ts_t_adj.dropna()
ts_t_adj.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ts_t_adj = ts_month_avg.diff().dropna()
ts_t_adj.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#apply adf test on the series
print(adf_test(ts_t_adj))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.795995e+00
# p-value                        2.300252e-09
# #Lags Used                     1.000000e+01
# Number of Observations Used    5.500000e+01
# Critical Value (1%)           -3.555273e+00
# Critical Value (5%)           -2.915731e+00
# Critical Value (10%)          -2.595670e+00
# dtype: float64
# None

# %%
ts_s_adj = ts_t_adj - ts_t_adj.shift(12)
ts_s_adj = ts_s_adj.dropna()
ts_s_adj.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ts_s_adj = ts_t_adj.diff(12).dropna()
ts_s_adj.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Plotting the ACF and PACF Plot of the Trend and Seasonally adjusted Time Series data
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_t_adj, lags=24)
matplotlib.pyplot.show()
plot_pacf(ts_t_adj, lags = 24)
matplotlib.pyplot.show()

# %%
p = range(0, 3)
d = range(1, 2)
q = range(0, 4)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
seasonal_pdq
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 12)
# SARIMAX: (0, 1, 2) x (0, 1, 3, 12)
# [(0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (0, 1, 3, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (1, 1, 3, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12),
#  (2, 1, 3, 12)]

# %%
list(itertools.product(p, d, q))
# Out:
# [(0, 1, 0),
#  (0, 1, 1),
#  (0, 1, 2),
#  (0, 1, 3),
#  (1, 1, 0),
#  (1, 1, 1),
#  (1, 1, 2),
#  (1, 1, 3),
#  (2, 1, 0),
#  (2, 1, 1),
#  (2, 1, 2),
#  (2, 1, 3)]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts_s_adj,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# A(0, 1, 3)x(1, 1, 0, 12)12 - AIC:484.115359979835
# Optimization terminated successfully.
#          Current function value: 4.330005
#          Iterations: 6
#          Function evaluations: 496
# ARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:479.64050960586
# Optimization terminated successfully.
#          Current function value: 4.326154
#          Iterations: 7
#          Function evaluations: 634
# ARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:481.22466275322375
# Optimization terminated successfully.
#          Current function value: 4.324506
#          Iterations: 6
#          Function evaluations: 627
# ARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:483.04663232129843
# Optimization terminated successfully.
#          Current function value: 4.316638
#          Iterations: 5
#          Function evaluations: 439
# ARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:478.19691009036524
# Optimization terminated successfully.
#          Current function value: 4.316090
#          Iterations: 5
#          Function evaluations: 496
# ARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:480.13772795702204
# Optimization terminated successfully.
#          Current function value: 4.314651
#          Iterations: 6
#          Function evaluations: 617
# ARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:481.9823052572512
# Optimization terminated successfully.
#          Current function value: 4.313105
#          Iterations: 7
#          Function evaluations: 797
# ARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:483.8153660837051
# Optimization terminated successfully.
#          Current function value: 4.772084
#          Iterations: 1
#          Function evaluations: 22
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:519.3850871907587
# Optimization terminated successfully.
#          Current function value: 4.581251
#          Iterations: 5
#          Function evaluations: 201
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:500.77508658515484
# Optimization terminated successfully.
#          Current function value: 4.502104
#          Iterations: 6
#          Function evaluations: 309
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:494.2272053495107
# Optimization terminated successfully.
#          Current function value: 4.490746
#          Iterations: 5
#          Function evaluations: 322
# ARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:495.0006175002035
# Optimization terminated successfully.
#          Current function value: 4.595341
#          Iterations: 3
#          Function evaluations: 118
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:502.29680252356115
# Optimization terminated successfully.
#          Current function value: 4.516062
#          Iterations: 8
#          Function evaluations: 399
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:495.7347114860752
# Optimization terminated successfully.
#          Current function value: 4.497177
#          Iterations: 7
#          Function evaluations: 425
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:495.6951553463199
# Optimization terminated successfully.
#          Current function value: 4.501524
#          Iterations: 6
#          Function evaluations: 450
# ARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:498.1645452482297
# Optimization terminated successfully.
#          Current function value: 4.469404
#          Iterations: 5
#          Function evaluations: 248
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:490.6956675322839
# Optimization terminated successfully.
#          Current function value: 4.466553
#          Iterations: 7
#          Function evaluations: 419
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:492.3877699120273
# Optimization terminated successfully.
#          Current function value: 4.455164
#          Iterations: 14
#          Function evaluations: 1028
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:493.1576779462322
# Optimization terminated successfully.
#          Current function value: 4.451929
#          Iterations: 12
#          Function evaluations: 1019
# ARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:494.8083346034353
# Optimization terminated successfully.
#          Current function value: 4.593357
#          Iterations: 3
#          Function evaluations: 113
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:502.0825571030888
# Optimization terminated successfully.
#          Current function value: 4.406940
#          Iterations: 4
#          Function evaluations: 268
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:483.9495174306197
# Optimization terminated successfully.
#          Current function value: 4.345999
#          Iterations: 7
#          Function evaluations: 508
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:479.36786704781537
# Optimization terminated successfully.
#          Current function value: 4.345146
#          Iterations: 6
#          Function evaluations: 497
# ARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:481.27574773034496
# Optimization terminated successfully.
#          Current function value: 4.417558
#          Iterations: 4
#          Function evaluations: 199
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:485.09629585811075
# Optimization terminated successfully.
#          Current function value: 4.355701
#          Iterations: 6
#          Function evaluations: 439
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:480.4157239020564
# Optimization terminated successfully.
#          Current function value: 4.348451
#          Iterations: 9
#          Function evaluations: 724
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:481.6326996855456
# Optimization terminated successfully.
#          Current function value: 4.346643
#          Iterations: 6
#          Function evaluations: 576
# ARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:483.4374756943523
# Optimization terminated successfully.
#          Current function value: 4.333619
#          Iterations: 5
#          Function evaluations: 375
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:478.03090455143854
# Optimization terminated successfully.
#          Current function value: 4.331609
#          Iterations: 7
#          Function evaluations: 570
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:479.8137866911437
# Optimization terminated successfully.
#          Current function value: 4.323523
#          Iterations: 9
#          Function evaluations: 826
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:480.94043391853353
# Optimization terminated successfully.
#          Current function value: 4.322490
#          Iterations: 8
#          Function evaluations: 820
# ARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:482.82895622139614
# Optimization terminated successfully.
#          Current function value: 4.575978
#          Iterations: 6
#          Function evaluations: 462
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:502.2055750884902
# Optimization terminated successfully.
#          Current function value: 4.381144
#          Iterations: 9
#          Function evaluations: 605
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:483.16350091689156
# Optimization terminated successfully.
#          Current function value: 4.319638
#          Iterations: 11
#          Function evaluations: 877
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:478.5208948983648
# Optimization terminated successfully.
#          Current function value: 4.346823
#          Iterations: 4
#          Function evaluations: 402
# ARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:483.45690961729093
# Optimization terminated successfully.
#          Current function value: 4.391515
#          Iterations: 7
#          Function evaluations: 507
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:484.28358618109456
# Optimization terminated successfully.
#          Current function value: 4.323656
#          Iterations: 11
#          Function evaluations: 848
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:478.95481092495874
# Optimization terminated successfully.
#          Current function value: 4.317068
#          Iterations: 12
#          Function evaluations: 1060
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:480.2433925026824
# Optimization terminated successfully.
#          Current function value: 4.313705
#          Iterations: 10
#          Function evaluations: 1031
# ARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:481.88012963728585
# Optimization terminated successfully.
#          Current function value: 4.334055
#          Iterations: 4
#          Function evaluations: 359
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:480.07791425673054
# Optimization terminated successfully.
#          Current function value: 4.325159
#          Iterations: 9
#          Function evaluations: 816
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:481.11712434612156
# Optimization terminated successfully.
#          Current function value: 4.323567
#          Iterations: 9
#          Function evaluations: 910
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:482.94522549580444
# Optimization terminated successfully.
#          Current function value: 4.322461
#          Iterations: 8
#          Function evaluations: 904
# ARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:484.82583362691264
# Optimization terminated successfully.
#          Current function value: 4.557498
#          Iterations: 5
#          Function evaluations: 417
# ARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:502.20977344463734
# Optimization terminated successfully.
#          Current function value: 4.375434
#          Iterations: 5
#          Function evaluations: 421
# ARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:484.5469059465829
# Optimization terminated successfully.
#          Current function value: 4.324721
#          Iterations: 6
#          Function evaluations: 621
# ARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:481.069898054128
# Optimization terminated successfully.
#          Current function value: 4.323335
#          Iterations: 5
#          Function evaluations: 607
# ARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:482.92022081809324
# Optimization terminated successfully.
#          Current function value: 4.370110
#          Iterations: 5
#          Function evaluations: 440
# ARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:483.97186951359623
# Optimization terminated successfully.
#          Current function value: 4.326659
#          Iterations: 8
#          Function evaluations: 827
# ARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:481.2791483236215
# Optimization terminated successfully.
#          Current function value: 4.327784
#          Iterations: 9
#          Function evaluations: 993
# ARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:483.40066926298726
# Optimization terminated successfully.
#          Current function value: 4.323866
#          Iterations: 6
#          Function evaluations: 765
# ARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:484.9775207341207
# Optimization terminated successfully.
#          Current function value: 4.326774
#          Iterations: 5
#          Function evaluations: 482
# ARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:481.2915650481277
# Optimization terminated successfully.
#          Current function value: 4.295719
#          Iterations: 13
#          Function evaluations: 1308
# ARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:479.93769324668153
# Optimization terminated successfully.
#          Current function value: 4.313665
#          Iterations: 9
#          Function evaluations: 1092
# ARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:483.8758422227259
# Optimization terminated successfully.
#          Current function value: 4.313169
#          Iterations: 8
#          Function evaluations: 1064
# ARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:485.8222941723856
# Optimization terminated successfully.
#          Current function value: 4.709966
#          Iterations: 2
#          Function evaluations: 73
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:514.6763742636415
# Optimization terminated successfully.
#          Current function value: 4.527808
#          Iterations: 5
#          Function evaluations: 259
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:497.0032478523194
# Optimization terminated successfully.
#          Current function value: 4.464752
#          Iterations: 6
#          Function evaluations: 380
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:492.1932011153951
# Optimization terminated successfully.
#          Current function value: 4.460529
#          Iterations: 4
#          Function evaluations: 308
# ARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:493.73715749241705
# Optimization terminated successfully.
#          Current function value: 4.531280
#          Iterations: 4
#          Function evaluations: 205
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:497.37820806211727
# Optimization terminated successfully.
#          Current function value: 4.473436
#          Iterations: 6
#          Function evaluations: 370
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:493.1311366229098
# Optimization terminated successfully.
#          Current function value: 4.462450
#          Iterations: 8
#          Function evaluations: 584
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:493.94459806119744
# Optimization terminated successfully.
#          Current function value: 4.465261
#          Iterations: 6
#          Function evaluations: 508
# ARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:496.2482195622425
# Optimization terminated successfully.
#          Current function value: 4.449376
#          Iterations: 5
#          Function evaluations: 303
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:490.53260027487966
# Optimization terminated successfully.
#          Current function value: 4.441676
#          Iterations: 9
#          Function evaluations: 639
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:491.70099972118305
# Optimization terminated successfully.
#          Current function value: 4.438370
#          Iterations: 9
#          Function evaluations: 772
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:493.34400435451164
# Optimization terminated successfully.
#          Current function value: 4.430151
#          Iterations: 11
#          Function evaluations: 1059
# ARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:494.4562933425237
# Optimization terminated successfully.
#          Current function value: 4.587909
#          Iterations: 3
#          Function evaluations: 155
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:503.4942136552702
# Optimization terminated successfully.
#          Current function value: 4.399570
#          Iterations: 5
#          Function evaluations: 372
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:485.15357396678473
# Optimization terminated successfully.
#          Current function value: 4.339397
#          Iterations: 7
#          Function evaluations: 577
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:480.6548663384529
# Optimization terminated successfully.
#          Current function value: 4.338023
#          Iterations: 5
#          Function evaluations: 456
# ARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:482.50649685065446
# Optimization terminated successfully.
#          Current function value: 4.404197
#          Iterations: 4
#          Function evaluations: 242
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:485.6532457306559
# Optimization terminated successfully.
#          Current function value: 4.345649
#          Iterations: 8
#          Function evaluations: 651
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:481.3300956452716
# Optimization terminated successfully.
#          Current function value: 4.338929
#          Iterations: 8
#          Function evaluations: 749
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:482.6043479794352
# Optimization terminated successfully.
#          Current function value: 4.339391
#          Iterations: 7
#          Function evaluations: 733
# ARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:484.65426316886226
# Optimization terminated successfully.
#          Current function value: 4.328091
#          Iterations: 5
#          Function evaluations: 432
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:479.4338801824081
# Optimization terminated successfully.
#          Current function value: 4.326144
#          Iterations: 6
#          Function evaluations: 565
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:481.2235254454033
# Optimization terminated successfully.
#          Current function value: 4.320119
#          Iterations: 9
#          Function evaluations: 937
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:482.5728777789833
# Optimization terminated successfully.
#          Current function value: 4.319138
#          Iterations: 9
#          Function evaluations: 1029
# ARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:484.46685810904177
# Optimization terminated successfully.
#          Current function value: 4.588443
#          Iterations: 3
#          Function evaluations: 232
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:505.5518619382887
# Optimization terminated successfully.
#          Current function value: 4.402153
#          Iterations: 4
#          Function evaluations: 343
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:487.4324704228964
# Optimization terminated successfully.
#          Current function value: 4.343480
#          Iterations: 6
#          Function evaluations: 567
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:483.0958266205626
# Optimization terminated successfully.
#          Current function value: 4.341701
#          Iterations: 5
#          Function evaluations: 540
# ARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:484.9037062972172
# Optimization terminated successfully.
#          Current function value: 4.405591
#          Iterations: 4
#          Function evaluations: 292
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:487.80382816620414
# Optimization terminated successfully.
#          Current function value: 4.350435
#          Iterations: 6
#          Function evaluations: 555
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:483.8469856502653
# Optimization terminated successfully.
#          Current function value: 4.342710
#          Iterations: 8
#          Function evaluations: 807
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:485.01269746659716
# Optimization terminated successfully.
#          Current function value: 4.343445
#          Iterations: 6
#          Function evaluations: 703
# ARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:487.0920668798537
# Optimization terminated successfully.
#          Current function value: 4.331746
#          Iterations: 5
#          Function evaluations: 489
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:481.8285708293305
# Optimization terminated successfully.
#          Current function value: 4.314693
#          Iterations: 14
#          Function evaluations: 1425
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:481.98682411565096
# Optimization terminated successfully.
#          Current function value: 4.322312
#          Iterations: 9
#          Function evaluations: 1019
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:484.8097020955698
# Optimization terminated successfully.
#          Current function value: 4.321462
#          Iterations: 8
#          Function evaluations: 998
# ARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:486.7178619027617
# Optimization terminated successfully.
#          Current function value: 4.557490
#          Iterations: 8
#          Function evaluations: 631
# ARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:504.2088998371172
# Optimization terminated successfully.
#          Current function value: 4.371745
#          Iterations: 7
#          Function evaluations: 667
# ARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:486.14850397030887
# Optimization terminated successfully.
#          Current function value: 4.303864
#          Iterations: 10
#          Function evaluations: 1131
# ARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:480.8173492865078
# Optimization terminated successfully.
#          Current function value: 4.299102
#          Iterations: 9
#          Function evaluations: 1065
# ARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:482.30303966588235
# Optimization terminated successfully.
#          Current function value: 4.359630
#          Iterations: 13
#          Function evaluations: 1129
# ARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:484.84001690976874
# Optimization terminated successfully.
#          Current function value: 4.306677
#          Iterations: 8
#          Function evaluations: 845
# ARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:481.12116601073257
# Optimization terminated successfully.
#          Current function value: 4.303503
#          Iterations: 10
#          Function evaluations: 1193
# ARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:482.7782942093058
# Optimization terminated successfully.
#          Current function value: 4.302998
#          Iterations: 10
#          Function evaluations: 1278
# ARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:484.7238369587888
# Optimization terminated successfully.
#          Current function value: 4.333636
#          Iterations: 6
#          Function evaluations: 571
# ARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:484.0327175860277
# Optimization terminated successfully.
#          Current function value: 4.327412
#          Iterations: 8
#          Function evaluations: 861
# ARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:485.3605452684971
# Optimization terminated successfully.
#          Current function value: 4.293052
#          Iterations: 9
#          Function evaluations: 1165
# ARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:483.6496677004626
# Optimization terminated successfully.
#          Current function value: 4.295545
#          Iterations: 11
#          Function evaluations: 1491
# ARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:485.91888721717174

# %%
pdq[1]
# Out:
# (0, 1, 1)

# %%
df = pd.DataFrame()

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts_s_adj,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            #print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            print('ARIMA{}x{}12'.format(param, param_seasonal))

            data = {'p': param, 'ps': param_seasonal, 'AIC':results.aic }
            df = df.append(data, ignore_index=True)

        except:
            continue
# Out:
# MA(0, 1, 2)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.343094
#          Iterations: 6
#          Function evaluations: 440
# ARIMA(0, 1, 2)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.344172
#          Iterations: 4
#          Function evaluations: 359
# ARIMA(0, 1, 2)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.408721
#          Iterations: 4
#          Function evaluations: 191
# ARIMA(0, 1, 2)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.352287
#          Iterations: 7
#          Function evaluations: 423
# ARIMA(0, 1, 2)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.346295
#          Iterations: 7
#          Function evaluations: 564
# ARIMA(0, 1, 2)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.342859
#          Iterations: 6
#          Function evaluations: 572
# ARIMA(0, 1, 2)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.333395
#          Iterations: 5
#          Function evaluations: 373
# ARIMA(0, 1, 2)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.332803
#          Iterations: 6
#          Function evaluations: 506
# ARIMA(0, 1, 2)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323085
#          Iterations: 9
#          Function evaluations: 802
# ARIMA(0, 1, 2)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.322395
#          Iterations: 8
#          Function evaluations: 816
# ARIMA(0, 1, 2)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.576832
#          Iterations: 2
#          Function evaluations: 156
# ARIMA(0, 1, 3)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.384425
#          Iterations: 5
#          Function evaluations: 350
# ARIMA(0, 1, 3)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.324626
#          Iterations: 5
#          Function evaluations: 431
# ARIMA(0, 1, 3)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323519
#          Iterations: 5
#          Function evaluations: 487
# ARIMA(0, 1, 3)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.389957
#          Iterations: 4
#          Function evaluations: 241
# ARIMA(0, 1, 3)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.330005
#          Iterations: 6
#          Function evaluations: 496
# ARIMA(0, 1, 3)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.326154
#          Iterations: 7
#          Function evaluations: 634
# ARIMA(0, 1, 3)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.324506
#          Iterations: 6
#          Function evaluations: 627
# ARIMA(0, 1, 3)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.316638
#          Iterations: 5
#          Function evaluations: 439
# ARIMA(0, 1, 3)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.316090
#          Iterations: 5
#          Function evaluations: 496
# ARIMA(0, 1, 3)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.314651
#          Iterations: 6
#          Function evaluations: 617
# ARIMA(0, 1, 3)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.313105
#          Iterations: 7
#          Function evaluations: 797
# ARIMA(0, 1, 3)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.772084
#          Iterations: 1
#          Function evaluations: 22
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.581251
#          Iterations: 5
#          Function evaluations: 201
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.502104
#          Iterations: 6
#          Function evaluations: 309
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.490746
#          Iterations: 5
#          Function evaluations: 322
# ARIMA(1, 1, 0)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.595341
#          Iterations: 3
#          Function evaluations: 118
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.516062
#          Iterations: 8
#          Function evaluations: 399
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.497177
#          Iterations: 7
#          Function evaluations: 425
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.501524
#          Iterations: 6
#          Function evaluations: 450
# ARIMA(1, 1, 0)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.469404
#          Iterations: 5
#          Function evaluations: 248
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.466553
#          Iterations: 7
#          Function evaluations: 419
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.455164
#          Iterations: 14
#          Function evaluations: 1028
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.451929
#          Iterations: 12
#          Function evaluations: 1019
# ARIMA(1, 1, 0)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.593357
#          Iterations: 3
#          Function evaluations: 113
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.406940
#          Iterations: 4
#          Function evaluations: 268
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.345999
#          Iterations: 7
#          Function evaluations: 508
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.345146
#          Iterations: 6
#          Function evaluations: 497
# ARIMA(1, 1, 1)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.417558
#          Iterations: 4
#          Function evaluations: 199
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.355701
#          Iterations: 6
#          Function evaluations: 439
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.348451
#          Iterations: 9
#          Function evaluations: 724
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.346643
#          Iterations: 6
#          Function evaluations: 576
# ARIMA(1, 1, 1)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.333619
#          Iterations: 5
#          Function evaluations: 375
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.331609
#          Iterations: 7
#          Function evaluations: 570
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323523
#          Iterations: 9
#          Function evaluations: 826
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.322490
#          Iterations: 8
#          Function evaluations: 820
# ARIMA(1, 1, 1)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.575978
#          Iterations: 6
#          Function evaluations: 462
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.381144
#          Iterations: 9
#          Function evaluations: 605
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.319638
#          Iterations: 11
#          Function evaluations: 877
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.346823
#          Iterations: 4
#          Function evaluations: 402
# ARIMA(1, 1, 2)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.391515
#          Iterations: 7
#          Function evaluations: 507
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323656
#          Iterations: 11
#          Function evaluations: 848
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.317068
#          Iterations: 12
#          Function evaluations: 1060
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.313705
#          Iterations: 10
#          Function evaluations: 1031
# ARIMA(1, 1, 2)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.334055
#          Iterations: 4
#          Function evaluations: 359
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.325159
#          Iterations: 9
#          Function evaluations: 816
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323567
#          Iterations: 9
#          Function evaluations: 910
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.322461
#          Iterations: 8
#          Function evaluations: 904
# ARIMA(1, 1, 2)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.557498
#          Iterations: 5
#          Function evaluations: 417
# ARIMA(1, 1, 3)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.375434
#          Iterations: 5
#          Function evaluations: 421
# ARIMA(1, 1, 3)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.324721
#          Iterations: 6
#          Function evaluations: 621
# ARIMA(1, 1, 3)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323335
#          Iterations: 5
#          Function evaluations: 607
# ARIMA(1, 1, 3)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.370110
#          Iterations: 5
#          Function evaluations: 440
# ARIMA(1, 1, 3)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.326659
#          Iterations: 8
#          Function evaluations: 827
# ARIMA(1, 1, 3)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.327784
#          Iterations: 9
#          Function evaluations: 993
# ARIMA(1, 1, 3)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.323866
#          Iterations: 6
#          Function evaluations: 765
# ARIMA(1, 1, 3)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.326774
#          Iterations: 5
#          Function evaluations: 482
# ARIMA(1, 1, 3)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.295719
#          Iterations: 13
#          Function evaluations: 1308
# ARIMA(1, 1, 3)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.313665
#          Iterations: 9
#          Function evaluations: 1092
# ARIMA(1, 1, 3)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.313169
#          Iterations: 8
#          Function evaluations: 1064
# ARIMA(1, 1, 3)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.709966
#          Iterations: 2
#          Function evaluations: 73
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.527808
#          Iterations: 5
#          Function evaluations: 259
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.464752
#          Iterations: 6
#          Function evaluations: 380
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.460529
#          Iterations: 4
#          Function evaluations: 308
# ARIMA(2, 1, 0)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.531280
#          Iterations: 4
#          Function evaluations: 205
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.473436
#          Iterations: 6
#          Function evaluations: 370
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.462450
#          Iterations: 8
#          Function evaluations: 584
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.465261
#          Iterations: 6
#          Function evaluations: 508
# ARIMA(2, 1, 0)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.449376
#          Iterations: 5
#          Function evaluations: 303
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.441676
#          Iterations: 9
#          Function evaluations: 639
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.438370
#          Iterations: 9
#          Function evaluations: 772
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.430151
#          Iterations: 11
#          Function evaluations: 1059
# ARIMA(2, 1, 0)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.587909
#          Iterations: 3
#          Function evaluations: 155
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.399570
#          Iterations: 5
#          Function evaluations: 372
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.339397
#          Iterations: 7
#          Function evaluations: 577
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.338023
#          Iterations: 5
#          Function evaluations: 456
# ARIMA(2, 1, 1)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.404197
#          Iterations: 4
#          Function evaluations: 242
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.345649
#          Iterations: 8
#          Function evaluations: 651
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.338929
#          Iterations: 8
#          Function evaluations: 749
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.339391
#          Iterations: 7
#          Function evaluations: 733
# ARIMA(2, 1, 1)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.328091
#          Iterations: 5
#          Function evaluations: 432
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.326144
#          Iterations: 6
#          Function evaluations: 565
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.320119
#          Iterations: 9
#          Function evaluations: 937
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.319138
#          Iterations: 9
#          Function evaluations: 1029
# ARIMA(2, 1, 1)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.588443
#          Iterations: 3
#          Function evaluations: 232
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.402153
#          Iterations: 4
#          Function evaluations: 343
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.343480
#          Iterations: 6
#          Function evaluations: 567
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.341701
#          Iterations: 5
#          Function evaluations: 540
# ARIMA(2, 1, 2)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.405591
#          Iterations: 4
#          Function evaluations: 292
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.350435
#          Iterations: 6
#          Function evaluations: 555
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.342710
#          Iterations: 8
#          Function evaluations: 807
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.343445
#          Iterations: 6
#          Function evaluations: 703
# ARIMA(2, 1, 2)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.331746
#          Iterations: 5
#          Function evaluations: 489
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.314693
#          Iterations: 14
#          Function evaluations: 1425
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.322312
#          Iterations: 9
#          Function evaluations: 1019
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.321462
#          Iterations: 8
#          Function evaluations: 998
# ARIMA(2, 1, 2)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.557490
#          Iterations: 8
#          Function evaluations: 631
# ARIMA(2, 1, 3)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.371745
#          Iterations: 7
#          Function evaluations: 667
# ARIMA(2, 1, 3)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.303864
#          Iterations: 10
#          Function evaluations: 1131
# ARIMA(2, 1, 3)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.299102
#          Iterations: 9
#          Function evaluations: 1065
# ARIMA(2, 1, 3)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.359630
#          Iterations: 13
#          Function evaluations: 1129
# ARIMA(2, 1, 3)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.306677
#          Iterations: 8
#          Function evaluations: 845
# ARIMA(2, 1, 3)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.303503
#          Iterations: 10
#          Function evaluations: 1193
# ARIMA(2, 1, 3)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.302998
#          Iterations: 10
#          Function evaluations: 1278
# ARIMA(2, 1, 3)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.333636
#          Iterations: 6
#          Function evaluations: 571
# ARIMA(2, 1, 3)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.327412
#          Iterations: 8
#          Function evaluations: 861
# ARIMA(2, 1, 3)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.293052
#          Iterations: 9
#          Function evaluations: 1165
# ARIMA(2, 1, 3)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.295545
#          Iterations: 11
#          Function evaluations: 1491
# ARIMA(2, 1, 3)x(2, 1, 3, 12)12

# %%
df.sort_values(by="AIC",ascending=False)
# Out:
#            AIC          p             ps
# 0   537.732834  (0, 1, 0)  (0, 1, 0, 12)
# 48  519.385087  (1, 1, 0)  (0, 1, 0, 12)
# 1   515.129386  (0, 1, 0)  (0, 1, 1, 12)
# 96  514.676374  (2, 1, 0)  (0, 1, 0, 12)
# 4   512.642411  (0, 1, 0)  (1, 1, 0, 12)
# ..         ...        ...            ...
# 68  478.030905  (1, 1, 1)  (2, 1, 0, 12)
# 32  478.006643  (0, 1, 2)  (2, 1, 0, 12)
# 14  477.952978  (0, 1, 1)  (0, 1, 2, 12)
# 21  477.823472  (0, 1, 1)  (2, 1, 1, 12)
# 20  476.062758  (0, 1, 1)  (2, 1, 0, 12)
#
# [144 rows x 3 columns]

# %%
#ARIMA(0, 1, 1)x(2, 1, 0, 12)
mod = sm.tsa.statespace.SARIMAX(ts_s_adj,
                                order=(0, 1, 0),
                                seasonal_order=(0, 1, 0, 12))
results = mod.fit(method = 'powell')
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 4.960489
#          Iterations: 2
#          Function evaluations: 33
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      2.769e+04   6828.174      4.055      0.000    1.43e+04    4.11e+04
# ==============================================================================

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = ts_s_adj.plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('AQI')
plt.legend()
plt.show()

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
df2 = pd.DataFrame()

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts_month_avg,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            #print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            print('ARIMA{}x{}12'.format(param, param_seasonal))

            data = {'p': param, 'ps': param_seasonal, 'AIC':results.aic }
            df2 = df2.append(data, ignore_index=True)

        except:
            continue
# Out:
# 0
# ARIMA(0, 1, 2)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.176970
#          Iterations: 5
#          Function evaluations: 301
# ARIMA(0, 1, 2)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.172021
#          Iterations: 5
#          Function evaluations: 374
# ARIMA(0, 1, 2)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.193541
#          Iterations: 6
#          Function evaluations: 294
# ARIMA(0, 1, 2)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.173882
#          Iterations: 5
#          Function evaluations: 309
# ARIMA(0, 1, 2)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.173923
#          Iterations: 5
#          Function evaluations: 360
# ARIMA(0, 1, 2)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.174117
#          Iterations: 6
#          Function evaluations: 504
# ARIMA(0, 1, 2)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.176547
#          Iterations: 5
#          Function evaluations: 300
# ARIMA(0, 1, 2)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.174358
#          Iterations: 5
#          Function evaluations: 357
# ARIMA(0, 1, 2)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.174019
#          Iterations: 5
#          Function evaluations: 410
# ARIMA(0, 1, 2)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.171011
#          Iterations: 5
#          Function evaluations: 474
# ARIMA(0, 1, 2)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.316210
#          Iterations: 4
#          Function evaluations: 190
# ARIMA(0, 1, 3)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.166740
#          Iterations: 5
#          Function evaluations: 311
# ARIMA(0, 1, 3)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.155863
#          Iterations: 5
#          Function evaluations: 364
# ARIMA(0, 1, 3)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.152283
#          Iterations: 5
#          Function evaluations: 427
# ARIMA(0, 1, 3)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.179052
#          Iterations: 6
#          Function evaluations: 357
# ARIMA(0, 1, 3)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.154018
#          Iterations: 5
#          Function evaluations: 369
# ARIMA(0, 1, 3)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.155732
#          Iterations: 6
#          Function evaluations: 513
# ARIMA(0, 1, 3)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.155859
#          Iterations: 5
#          Function evaluations: 482
# ARIMA(0, 1, 3)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.153715
#          Iterations: 5
#          Function evaluations: 349
# ARIMA(0, 1, 3)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.154486
#          Iterations: 5
#          Function evaluations: 412
# ARIMA(0, 1, 3)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.152973
#          Iterations: 5
#          Function evaluations: 469
# ARIMA(0, 1, 3)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.150000
#          Iterations: 6
#          Function evaluations: 619
# ARIMA(0, 1, 3)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.368790
#          Iterations: 2
#          Function evaluations: 44
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.236992
#          Iterations: 4
#          Function evaluations: 150
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.230500
#          Iterations: 3
#          Function evaluations: 155
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.228966
#          Iterations: 4
#          Function evaluations: 245
# ARIMA(1, 1, 0)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.250550
#          Iterations: 3
#          Function evaluations: 115
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.229714
#          Iterations: 4
#          Function evaluations: 204
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.230279
#          Iterations: 4
#          Function evaluations: 238
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.229997
#          Iterations: 4
#          Function evaluations: 283
# ARIMA(1, 1, 0)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.230596
#          Iterations: 4
#          Function evaluations: 193
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.229441
#          Iterations: 3
#          Function evaluations: 176
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.229783
#          Iterations: 3
#          Function evaluations: 211
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.228358
#          Iterations: 3
#          Function evaluations: 247
# ARIMA(1, 1, 0)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.313757
#          Iterations: 3
#          Function evaluations: 113
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.171941
#          Iterations: 5
#          Function evaluations: 310
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.165091
#          Iterations: 4
#          Function evaluations: 300
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.163497
#          Iterations: 5
#          Function evaluations: 431
# ARIMA(1, 1, 1)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.183371
#          Iterations: 4
#          Function evaluations: 213
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.163826
#          Iterations: 4
#          Function evaluations: 248
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.164682
#          Iterations: 4
#          Function evaluations: 310
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.164382
#          Iterations: 4
#          Function evaluations: 353
# ARIMA(1, 1, 1)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.165505
#          Iterations: 4
#          Function evaluations: 252
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.163613
#          Iterations: 4
#          Function evaluations: 293
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.164019
#          Iterations: 4
#          Function evaluations: 341
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.162437
#          Iterations: 4
#          Function evaluations: 389
# ARIMA(1, 1, 1)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.311806
#          Iterations: 5
#          Function evaluations: 245
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.168727
#          Iterations: 4
#          Function evaluations: 299
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.157749
#          Iterations: 3
#          Function evaluations: 255
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.153415
#          Iterations: 4
#          Function evaluations: 378
# ARIMA(1, 1, 2)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.175888
#          Iterations: 3
#          Function evaluations: 183
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.155289
#          Iterations: 5
#          Function evaluations: 431
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.157602
#          Iterations: 3
#          Function evaluations: 302
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.156700
#          Iterations: 3
#          Function evaluations: 333
# ARIMA(1, 1, 2)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.155087
#          Iterations: 4
#          Function evaluations: 282
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.155437
#          Iterations: 4
#          Function evaluations: 342
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.154517
#          Iterations: 5
#          Function evaluations: 480
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.151694
#          Iterations: 6
#          Function evaluations: 686
# ARIMA(1, 1, 2)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.312746
#          Iterations: 3
#          Function evaluations: 177
# ARIMA(1, 1, 3)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.163552
#          Iterations: 5
#          Function evaluations: 413
# ARIMA(1, 1, 3)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.151942
#          Iterations: 4
#          Function evaluations: 337
# ARIMA(1, 1, 3)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.148359
#          Iterations: 4
#          Function evaluations: 379
# ARIMA(1, 1, 3)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.173672
#          Iterations: 3
#          Function evaluations: 211
# ARIMA(1, 1, 3)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.150455
#          Iterations: 4
#          Function evaluations: 332
# ARIMA(1, 1, 3)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.153547
#          Iterations: 4
#          Function evaluations: 389
# ARIMA(1, 1, 3)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.151825
#          Iterations: 4
#          Function evaluations: 437
# ARIMA(1, 1, 3)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.148989
#          Iterations: 4
#          Function evaluations: 321
# ARIMA(1, 1, 3)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.150676
#          Iterations: 4
#          Function evaluations: 374
# ARIMA(1, 1, 3)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.148739
#          Iterations: 4
#          Function evaluations: 414
# ARIMA(1, 1, 3)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.145794
#          Iterations: 5
#          Function evaluations: 641
# ARIMA(1, 1, 3)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.358793
#          Iterations: 2
#          Function evaluations: 69
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.229847
#          Iterations: 4
#          Function evaluations: 195
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.222852
#          Iterations: 3
#          Function evaluations: 193
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.220452
#          Iterations: 4
#          Function evaluations: 292
# ARIMA(2, 1, 0)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.239961
#          Iterations: 3
#          Function evaluations: 146
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.221807
#          Iterations: 4
#          Function evaluations: 245
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.221998
#          Iterations: 4
#          Function evaluations: 281
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.221861
#          Iterations: 4
#          Function evaluations: 328
# ARIMA(2, 1, 0)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.222485
#          Iterations: 4
#          Function evaluations: 236
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.221272
#          Iterations: 3
#          Function evaluations: 210
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.221657
#          Iterations: 3
#          Function evaluations: 248
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.219684
#          Iterations: 4
#          Function evaluations: 374
# ARIMA(2, 1, 0)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.312039
#          Iterations: 8
#          Function evaluations: 400
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.166464
#          Iterations: 7
#          Function evaluations: 433
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.152214
#          Iterations: 7
#          Function evaluations: 529
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.145397
#          Iterations: 8
#          Function evaluations: 751
# ARIMA(2, 1, 1)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.173351
#          Iterations: 14
#          Function evaluations: 822
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.149860
#          Iterations: 7
#          Function evaluations: 502
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.153440
#          Iterations: 8
#          Function evaluations: 695
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.151940
#          Iterations: 8
#          Function evaluations: 794
# ARIMA(2, 1, 1)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.146668
#          Iterations: 7
#          Function evaluations: 563
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.149783
#          Iterations: 6
#          Function evaluations: 507
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.145641
#          Iterations: 10
#          Function evaluations: 987
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.138315
#          Iterations: 10
#          Function evaluations: 1153
# ARIMA(2, 1, 1)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.311310
#          Iterations: 4
#          Function evaluations: 252
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.164986
#          Iterations: 6
#          Function evaluations: 500
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.146541
#          Iterations: 6
#          Function evaluations: 562
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.131657
#          Iterations: 11
#          Function evaluations: 1103
# ARIMA(2, 1, 2)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.171580
#          Iterations: 4
#          Function evaluations: 301
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.142593
#          Iterations: 7
#          Function evaluations: 613
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.143610
#          Iterations: 7
#          Function evaluations: 737
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.132536
#          Iterations: 13
#          Function evaluations: 1444
# ARIMA(2, 1, 2)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.139180
#          Iterations: 7
#          Function evaluations: 608
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.141589
#          Iterations: 7
#          Function evaluations: 745
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.123141
#          Iterations: 13
#          Function evaluations: 1435
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.125830
#          Iterations: 10
#          Function evaluations: 1259
# ARIMA(2, 1, 2)x(2, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.284806
#          Iterations: 4
#          Function evaluations: 299
# ARIMA(2, 1, 3)x(0, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.152269
#          Iterations: 7
#          Function evaluations: 605
# ARIMA(2, 1, 3)x(0, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.130291
#          Iterations: 10
#          Function evaluations: 988
# ARIMA(2, 1, 3)x(0, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.127193
#          Iterations: 11
#          Function evaluations: 1216
# ARIMA(2, 1, 3)x(0, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.174308
#          Iterations: 3
#          Function evaluations: 250
# ARIMA(2, 1, 3)x(1, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.125632
#          Iterations: 13
#          Function evaluations: 1256
# ARIMA(2, 1, 3)x(1, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.126688
#          Iterations: 16
#          Function evaluations: 1752
# ARIMA(2, 1, 3)x(1, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.126662
#          Iterations: 11
#          Function evaluations: 1339
# ARIMA(2, 1, 3)x(1, 1, 3, 12)12
# Optimization terminated successfully.
#          Current function value: 4.125232
#          Iterations: 8
#          Function evaluations: 778
# ARIMA(2, 1, 3)x(2, 1, 0, 12)12
# Optimization terminated successfully.
#          Current function value: 4.102957
#          Iterations: 16
#          Function evaluations: 1755
# ARIMA(2, 1, 3)x(2, 1, 1, 12)12
# Optimization terminated successfully.
#          Current function value: 4.105910
#          Iterations: 12
#          Function evaluations: 1426
# ARIMA(2, 1, 3)x(2, 1, 2, 12)12
# Optimization terminated successfully.
#          Current function value: 4.099764
#          Iterations: 13
#          Function evaluations: 1686
# ARIMA(2, 1, 3)x(2, 1, 3, 12)12

# %%
df2.sort_values(by="AIC",ascending=False)
# Out:
#             AIC          p             ps
# 0    591.870762  (0, 1, 0)  (0, 1, 0, 12)
# 96   590.078276  (2, 1, 0)  (0, 1, 0, 12)
# 48   589.417883  (1, 1, 0)  (0, 1, 0, 12)
# 84   587.908031  (1, 1, 3)  (0, 1, 0, 12)
# 120  587.715571  (2, 1, 2)  (0, 1, 0, 12)
# ..          ...        ...            ...
# 113  568.081259  (2, 1, 1)  (1, 1, 1, 12)
# 65   567.952703  (1, 1, 1)  (1, 1, 1, 12)
# 141  567.796269  (2, 1, 3)  (2, 1, 1, 12)
# 116  567.653486  (2, 1, 1)  (2, 1, 0, 12)
# 61   567.040051  (1, 1, 1)  (0, 1, 1, 12)
#
# [144 rows x 3 columns]

# %%
mod = sm.tsa.statespace.SARIMAX(ts_month_avg,
                                order=(0, 1, 0),
                                seasonal_order=(0, 1, 0, 12))
results = mod.fit(method = 'powell')
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 4.402021
#          Iterations: 2
#          Function evaluations: 37
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3247.5482    514.270      6.315      0.000    2239.598    4255.498
# ==============================================================================

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-01-01'), end=pd.to_datetime('2021-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = ts_month_avg.plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('AQI')
plt.legend()
plt.show()

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()
